# %% [markdown]
# <a href="https://colab.research.google.com/github/Pooja343-pal/Assignment-1/blob/main/predicthouseprice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
# %matplotlib inline

# %%
column_names=[]
df =pd.read_csv('C:/data.csv',column_names)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-223758000.py in <cell line: 0>()
# ----> 1 df =pd.read_csv('C:/data.csv',column_names)
#       2 df.head()
#
# NameError: name 'column_names' is not defined
